# %% [markdown]
# # Variables and variable types
#
# ## "Regular" variables
#
# 1. strings
# 1. integers
# 1. floats
#
# ## "Collection" variables
#
# 1. tuples
# 1. lists
# 1. sets
# 1. dictionaries
#
# From https://www.w3schools.com:
#
# - **Strings** are for storing text
# - **Integers** are for storing whole numbers, positive or negative (such as 123 or -456), without decimals.
# - **Floats** are for storing positive and negative numbers with a decimal point, like 35.3, or -2.34
# - **Lists** are collections which are ordered and changeable. Allows duplicate members.
# - **Tuples** are collections which are ordered and unchangeable. Allows duplicate members.
# - **Sets** are collections which are unordered, "unchangeable", and unindexed. No duplicate members.
# - **Dictionaries** are collections which are ordered and changeable. No duplicate members.

# %% [markdown]
# ## Strings

# %%
name = 'Camilla'

# %% [markdown]
# ## Integers

# %%
number = 13
# Out:
# 13

# %% [markdown]
# ## Floats

# %%
another_number = 18.25

# %% [markdown]
# ## Lists

# %%
my_variables = [3, 2, 78, 4]
my_variables[1] = 5
my_variables
# Out:
# [3, 5, 78, 4]

# %% [markdown]
# #python anser tallet 3 som nummer "0" i rækkefølgen og det er derfor tallet 2 der kommer op når man beder den finde 1. tal i rækken.
#
# man kan også ændre specifikket tals værdi i rækkefølgen, elelr gøre det med "number", "name" eller andet.

# %% [markdown]
# ## Tuples

# %%
shopping_list = ["apples", "pears", "bananas"]
shopping_tuple = ("apples", "pears" "bananas")
shopping_list[1]
# Out:
# 'pears'

# %%
shopping_list[1] = "grapes"
shopping_list
# Out:
# ['apples', 'grapes', 'bananas']

# %%
shopping_tuple[2]
shopping_tuple[1] ="grapes"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 shopping_tuple[2]
#       2 shopping_tuple[1] ="grapes"
#
# IndexError: tuple index out of range

# %% [markdown]
# ###
# list og tuples er basically the same, men ved lists kan man ændre et tals værdi og det kan man ikke ved tuples.

# %% [markdown]
# ## Sets

# %%
new_list =[4, 4, 7, 19, 21.25, 'i am a string']
my_set = set(new_list)
my_set
# Out:
# {19, 21.25, 4, 7, 'i am a string'}

# %% [markdown]
# ###
# you can mix types, so both integers, strings and floats.
#
# Sets are unordered - you can't go and ask for the number in position 2 fx.
# no duplicate members, so that is why one of the 4's is missing.
#
# It's the same random order everytime.
#
# you use sets when looking for words in texts or counting the number of tokens and types. like "does the word 'the' appear in this text"

# %% [markdown]
# ## Dictionaries

# %%
my_pet = {'name': 'D2',
         'species': 'cat',
         'likes': 'sleeping',
         'dislikes': 'loud noises',
         'age': 10}

# %%
items = ["grapes", "skyr", ["pepper", "salt", "sugar"], "milk", "rice"]
number = [1, 2, 7, 3]
priority = ["high", "high", "low", "high"]

# %%
shopping = {"items": items,"number": number, "priority": priority}

# %%
shopping['items']
# Out:
# ['grapes', 'skyr', ['pepper', 'salt', 'sugar'], 'milk', 'rice']

# %% [markdown]
# ###
# Man kan putte en liste inde i en liste, der er inde i en liste, man skal bare huske at bruge square brackets.

# %%
things = items

# %% [markdown]
# ###
# slicing
# type
# len
# pandas dataframes

# %%
a = [4, 5, 8, 5, 6, 7, 9, 10]
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 8

# %%
b = "i am a string"
len(b)
# Out:
# 13

# %%
a[3:]
# Out:
# [5, 6, 7, 9, 10]

# %% [markdown]
# ###
# len = length, der kan fortælle hvor mange characters der er i en string eller hvor mange tal der er i en liste.
#
# Slicing = skriv et tal og ":" efter, så vil den vise hvilke tal der kommer efter tallet.
#
# den sidste position i en talrække og -1 er basically den samme.
