# %% [markdown]
# # My First Notebook

# %% [markdown]
# In this notebook, I will learn about the basic types of variables in Python. They are:
# 1. strings
# 2. integers
# 3. floats
#
# lets go!

# %% [markdown]
# ## Strings

# %% [markdown]
# "citation marks" makes the words a character
#
# Strings can't be added to integers or floats
#
# #will ignore everything you write after

# %%
# here I attempt to use hashtags
fruit1 = "grapes"
#fruit = int(grapes)
fruit2 = "bananas"

fruit1 + fruit2
# Out:
# 'grapesbananas'

# %%
fruit1.replace('a','@')
# Out:
# 'gr@pes'

# %%
dir(fruit1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %% [markdown]
# ## Integers

# %% [markdown]
# whole numbers

# %% [markdown]
# ### experimenting with integers

# %%
chips = 2
cookies = 3
snacks = chips + cookies
print(chips, cookies, snacks)
# Out:
# 2 3 5

# %%
type(snacks)
# Out:
# int

# %%
snacks
# Out:
# 5

# %%
dir(snacks)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
# ...

# %% [markdown]
# ## Floats

# %% [markdown]
# numbers with decimals

# %% [markdown]
# ### experimenting with floats

# %%
cookies = 3.2

# %%
type(cookies)
# Out:
# float
